# %%
import numpy as np
from collections import deque
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, initializers, regularizers
from AtomasWrapper import AtomasWrapper

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
gpu_name = tf.test.gpu_device_name()
print(gpu_name)
# Out:
# Num GPUs Available:  1
# /device:GPU:0

# %%
# simple
def create_q_model():

    state = layers.Input(shape = (21,))

    layer1 = layers.Dense(
        units = 128, 
        activation = "relu",
        kernel_initializer = "he_normal",
        bias_initializer = initializers.Constant(0.01),
        bias_regularizer = regularizers.L2(1e-4),
        activity_regularizer = regularizers.L2(1e-5)
    )(state)

    bn1 = layers.BatchNormalization()(layer1)

    layer2 = layers.Dense(
        units = 128, 
        activation = "relu",
        kernel_initializer = "he_normal",
        bias_initializer = initializers.Constant(0.01),
        bias_regularizer = regularizers.L2(1e-4),
        activity_regularizer = regularizers.L2(1e-5)
    )(bn1)

    bn2 = layers.BatchNormalization()(layer2)

    layer3 = layers.Dense(
        units = 128, 
        activation = "relu",
        kernel_initializer = "he_normal",
        bias_initializer = initializers.Constant(0.01),
        bias_regularizer = regularizers.L2(1e-4),
        activity_regularizer = regularizers.L2(1e-5)
    )(bn2)

    bn3 = layers.BatchNormalization()(layer3)

    q_value = layers.Dense(
        units = 18, 
        activation = "linear",
        kernel_initializer = "he_normal",
        bias_initializer = initializers.Constant(0.01),
        bias_regularizer = regularizers.L2(1e-4),
        activity_regularizer = regularizers.L2(1e-5)
    )(bn3)

    return keras.Model(inputs = state, outputs = q_value)

# %%
model = create_q_model()
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 21)]              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               2816
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dense_3 (Dense)              (None, 18)                2322
# =================================================================
# Total params: 39,698
# Trainable params: 38,930
# Non-trainable params: 768
# _________________________________________________________________
# None

# %%
# training procedure adapted from Yale's S&DS 365: Intermediate Machine Learning, Assignment 4.3.

NUM_ACTIONS = 18

GAMMA = 0.3           # decay rate of past observations
STEP_SIZE = 1e-4        # step size
OBSERVE = 10000         # timesteps to observe before training
TRAINING = 10000000     # timesteps of observing + training
REPLAY_MEMORY = 10000   # number of previous transitions to remember
BATCH_SIZE = 64         # size of each batch
EPSILON = 0.2           # exploration probability

ILLEGAL_ACTION_Q_VALUE = -1000000

losses = []

# %%
def dql_atomas(model, optimizer, loss_function):

    # initiate game
    game = AtomasWrapper()

    # store the previous state, action and transitions
    history_data = deque()

    # get the first observation by checking the game
    current_state, num_legal_actions, reward, terminal = game.check()
  
    # training
    t = 0

    while t < TRAINING:

        if terminal or num_legal_actions == 0:
            game = AtomasWrapper()
            current_state, num_legal_actions, reward, terminal = game.check()
            if num_legal_actions == 0:
                print("WARNING: Invalid Ring Replaced")

        if np.random.rand(1)[0] < EPSILON:
            # random action
            action = np.random.choice(num_legal_actions)
        else:
            # compute the Q function
            current_state_tensor = tf.convert_to_tensor(current_state)
            current_state_tensor = tf.expand_dims(current_state_tensor, 0)
            q_value = model(current_state_tensor, training = True)
          
            # greedy action   
            action = tf.argmax(q_value[0][:num_legal_actions]).numpy()

        # take the action and observe the reward and the next state
        
        action_vec = np.zeros(NUM_ACTIONS)
        action_vec[action] = 1
        next_state, num_legal_actions, reward, terminal = game.step(action_vec)

        # store the observation
        history_data.append((current_state, action, reward, next_state, 
                            terminal, num_legal_actions))
        if len(history_data) > REPLAY_MEMORY:
            history_data.popleft()  # discard old data


        # train if done observing
        if t > OBSERVE:

            # sample a batch
            batch = random.sample(history_data, BATCH_SIZE)
            state_sample = np.array([d[0] for d in batch])
            action_sample = np.array([d[1] for d in batch])
            reward_sample = np.array([d[2] for d in batch])
            state_next_sample = np.array([d[3] for d in batch])
            terminal_sample = np.array([d[4] for d in batch])
            legal_actions_sample = np.array([d[5] for d in batch])

            # compute the updated Q-values for the samples
            future_rewards = model(tf.convert_to_tensor(state_next_sample), training = True).numpy()

            # only consider q-values of legal actions
            for batch_idx, rewards in enumerate(future_rewards):
                for action_idx, reward_val in enumerate(rewards):
                    if action_idx >= legal_actions_sample[batch_idx]:
                        reward_val = ILLEGAL_ACTION_Q_VALUE
            
            terminal_tensor = tf.convert_to_tensor([float(s) for s in terminal_sample])   
            updated_q_value = reward_sample + (GAMMA * tf.reduce_max(future_rewards, axis = 1))

            # If final frame set the last value to -1
            updated_q_value = updated_q_value * (1 - terminal_tensor) - (terminal_tensor)

            # train the model on the states and updated Q-values
            with tf.GradientTape() as tape:

                # compute the current Q-values for the samples
                current_q_value = model(state_sample, training = True)
                mask = tf.one_hot(action_sample, NUM_ACTIONS)
                current_q_value = tf.reduce_sum(tf.multiply(current_q_value, mask), axis = 1)

                # compute the loss
                loss = loss_function(updated_q_value, current_q_value)

            # backpropagation
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))

        else:
            loss = 0

        # update current state and counter
        current_state = next_state
        t += 1
        losses.append(loss)

        if t % 500 == 0: # originally 500
            print(f"STEP {t} | PHASE {'observe' if t <= OBSERVE else 'train'}", 
                  f"| ACTION {action} | REWARD {reward} | LOSS {loss}")
            if t > 10000 and t % 10000 == 0:
                model.save("dqn_model")
                wrapper = AtomasWrapper()
                wrapper.activate()

# %%
def train_atomas(start_from_ckpt = False, ckpt_path = None):

    np.random.seed(37)

    if start_from_ckpt:
        # if you want to start from a checkpoint
        model = keras.models.load_model("dqn_model")
    else:
        model = create_q_model()

    # specify the optimizer and loss function
    optimizer = keras.optimizers.SGD(learning_rate = STEP_SIZE, clipnorm = 1.0)
    loss_function = keras.losses.MeanSquaredError()

    # train model
    dql_atomas(model = model, optimizer = optimizer, loss_function = loss_function)

# %%
with tf.device(gpu_name):
    train_atomas(start_from_ckpt = True)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# STEP 500 | PHASE observe | ACTION 0 | REWARD 0 | LOSS 0
# STEP 1000 | PHASE observe | ACTION 0 | REWARD 0 | LOSS 0
# STEP 1500 | PHASE observe | ACTION 0 | REWARD 0 | LOSS 0
# STEP 2000 | PHASE observe | ACTION 0 | REWARD 0 | LOSS 0
# STEP 2500 | PHASE observe | ACTION 0 | REWARD 0 | LOSS 0
# STEP 3000 | PHASE observe | ACTION 0 | REWARD 0.0 | LOSS 0
# STEP 3500 | PHASE observe | ACTION 6 | REWARD 0 | LOSS 0
# STEP 4000 | PHASE observe | ACTION 0 | REWARD 0 | LOSS 0
# STEP 4500 | PHASE observe | ACTION 0 | REWARD 0 | LOSS 0
# STEP 5000 | PHASE observe | ACTION 0 | REWARD 0 | LOSS 0
# STEP 5500 | PHASE observe | ACTION 6 | REWARD 0.0 | LOSS 0
# STEP 6000 | PHASE observe | ACTION 0 | REWARD 0 | LOSS 0
# STEP 6500 | PHASE observe | ACTION 0 | REWARD 0 | LOSS 0
# STEP 7000 | PHASE observe | ACTION 0 | REWARD 0 | LOSS 0
# STEP 7500 | PHASE observe | ACTION 0 | REWARD 0 | LOSS 0
# STEP 8000 | PHASE observe | ACTION 8 | REWARD 0 | LOSS 0
# STEP 8500 | PHASE observe | ACTION 0 | REWARD 3 | LOSS 0
# STEP 9000 | PHASE observe | ACTION 0 | REWARD 0 | LOSS 0
# STEP 9500 | PHASE observe | ACTION 0 | REWARD 0 | LOSS 0
# STEP 10000 | PHASE observe | ACTION 0 | REWARD 0 | LOSS 0
# STEP 10500 | PHASE train | ACTION 0 | REWARD 31 | LOSS 21.615304946899414
# STEP 11000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 18.647043228149414
# STEP 11500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 22.020566940307617
# STEP 12000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 9.160177230834961
# STEP 12500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 3.0359275341033936
# STEP 13000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 28.788204193115234
# STEP 13500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 14.636261940002441
# STEP 14000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 48.76646041870117
# STEP 14500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 15.910079956054688
# STEP 15000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 18.809114456176758
# STEP 15500 | PHASE train | ACTION 6 | REWARD 0 | LOSS 2.3631834983825684
# STEP 16000 | PHASE train | ACTION 0 | REWARD 16 | LOSS 23.193370819091797
# STEP 16500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 2.113001823425293
# STEP 17000 | PHASE train | ACTION 8 | REWARD -10 | LOSS 12.410282135009766
# STEP 17500 | PHASE train | ACTION 0 | REWARD -10 | LOSS 21.663040161132812
# STEP 18000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 99.27010345458984
# STEP 18500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 79.41990661621094
# STEP 19000 | PHASE train | ACTION 0 | REWARD 4 | LOSS 3.96512508392334
# STEP 19500 | PHASE train | ACTION 0 | REWARD 6.0 | LOSS 99.05584716796875
# STEP 20000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 4.931460380554199
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: dqn_model\assets
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
#
# 	    Turns Taken: 0     ||     Score: 0     ||     Atom Count: 6
#
# 				Center Element: ( He )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( Li ) -- 4 -- ( He ) -- 5 -- ( He ) -- 6 --
#
# Select a Move
# > 0, Reward: 0
#
# 	    Turns Taken: 1     ||     Score: 0     ||     Atom Count: 7
#
# 				Center Element: ( He )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( He ) -- 7 --
#
# Select a Move
# > 2, Reward: 0
#
# 	    Turns Taken: 2     ||     Score: 0     ||     Atom Count: 8
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( He ) -- 4 -- ( He ) -- 5 -- ( Li ) -- 6 -- ( He ) -- 7 -- ( He ) -- 8 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 3     ||     Score: 0     ||     Atom Count: 9
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 --
#
# Select a Move
# > 8, Reward: 0
#
# 	    Turns Taken: 4     ||     Score: 0     ||     Atom Count: 10
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( He ) -- 8 -- ( H ) -- 9 -- ( He ) -- 10 --
#
# Select a Move
# > 6, Reward: 0
#
# 	    Turns Taken: 5     ||     Score: 0     ||     Atom Count: 11
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( He ) -- 9 -- ( H ) -- 10 -- ( He ) -- 11 --
#
# Select a Move
# > 0, Reward: 4
#
# 	    Turns Taken: 6     ||     Score: 4     ||     Atom Count: 10
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( Li ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( He ) -- 9 -- ( H ) -- 10 --
#
# Select a Move
# > 6, Reward: 0
#
# 	    Turns Taken: 7     ||     Score: 4     ||     Atom Count: 11
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( Li ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( Li ) -- 9 -- ( He ) -- 10 -- ( H ) -- 11 --
#
# Select a Move
# > 6, Reward: 0
#
# 	    Turns Taken: 8     ||     Score: 4     ||     Atom Count: 12
#
# 				Center Element: ( - )
#
#  -- 0 -- ( Li ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 -- ( He ) -- 11 -- ( H ) -- 12 --
#
# Select a Move
# > 0, Reward: 0
#
# 	    Turns Taken: 8     ||     Score: 4     ||     Atom Count: 11
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( Li ) -- 4 -- ( He ) -- 5 -- ( Li ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( Li ) -- 9 -- ( He ) -- 10 -- ( H ) -- 11 --
#
# Select a Move
# > 10, Reward: 0
#
# 	    Turns Taken: 9     ||     Score: 4     ||     Atom Count: 12
#
# 				Center Element: ( He )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( Li ) -- 4 -- ( He ) -- 5 -- ( Li ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( Li ) -- 9 -- ( He ) -- 10 -- ( Li ) -- 11 -- ( H ) -- 12 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 10     ||     Score: 4     ||     Atom Count: 13
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( Li ) -- 4 -- ( He ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 -- ( He ) -- 11 -- ( Li ) -- 12 -- ( H ) -- 13 --
#
# Select a Move
# > 3, Reward: 0
#
# 	    Turns Taken: 11     ||     Score: 4     ||     Atom Count: 14
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( + ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( He ) -- 7 -- ( Li ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 -- ( Li ) -- 11 -- ( He ) -- 12 -- ( Li ) -- 13 -- ( H ) -- 14 --
#
# Select a Move
# > 6, Reward: 0
#
# 	    Turns Taken: 12     ||     Score: 4     ||     Atom Count: 15
#
# 				Center Element: ( - )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( + ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( H ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 -- ( Li ) -- 11 -- ( Li ) -- 12 -- ( He ) -- 13 -- ( Li ) -- 14 -- ( H ) -- 15 --
#
# Select a Move
# > 7, Reward: 0
#
# 	    Turns Taken: 12     ||     Score: 4     ||     Atom Count: 14
#
# 				Center Element: ( He )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( + ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( H ) -- 7 -- ( Li ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 -- ( Li ) -- 11 -- ( He ) -- 12 -- ( Li ) -- 13 -- ( H ) -- 14 --
#
# Select a Move
# > 6, Reward: 0
#
# 	    Turns Taken: 13     ||     Score: 4     ||     Atom Count: 15
#
# 				Center Element: ( - )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( + ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( He ) -- 7 -- ( H ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 -- ( Li ) -- 11 -- ( Li ) -- 12 -- ( He ) -- 13 -- ( Li ) -- 14 -- ( H ) -- 15 --
#
# Select a Move
# > 7, Reward: 0
#
# 	    Turns Taken: 13     ||     Score: 4     ||     Atom Count: 14
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( + ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( He ) -- 7 -- ( Li ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 -- ( Li ) -- 11 -- ( He ) -- 12 -- ( Li ) -- 13 -- ( H ) -- 14 --
#
# Select a Move
# > 6, Reward: 0
#
# 	    Turns Taken: 14     ||     Score: 4     ||     Atom Count: 15
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( + ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( H ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 -- ( Li ) -- 11 -- ( Li ) -- 12 -- ( He ) -- 13 -- ( Li ) -- 14 -- ( H ) -- 15 --
#
# Select a Move
# > 6, Reward: 0
#
# 	    Turns Taken: 15     ||     Score: 4     ||     Atom Count: 16
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( He ) -- 2 -- ( He ) -- 3 -- ( + ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( + ) -- 7 -- ( H ) -- 8 -- ( He ) -- 9 -- ( Li ) -- 10 -- ( Li ) -- 11 -- ( Li ) -- 12 -- ( Li ) -- 13 -- ( He ) -- 14 -- ( Li ) -- 15 -- ( H ) -- 16 --
#
# Select a Move
# > 1, Reward: 4
#
# 	    Turns Taken: 16     ||     Score: 8     ||     Atom Count: 15
#
# 				Center Element: ( He )
#
#  -- 0 -- ( Li ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( He ) -- 5 -- ( + ) -- 6 -- ( H ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 -- ( Li ) -- 11 -- ( Li ) -- 12 -- ( He ) -- 13 -- ( Li ) -- 14 -- ( H ) -- 15 --
#
# Select a Move
# > 12, Reward: 0
#
# 	    Turns Taken: 17     ||     Score: 8     ||     Atom Count: 16
#
# 				Center Element: ( H )
#
#  -- 0 -- ( Li ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( He ) -- 5 -- ( + ) -- 6 -- ( H ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 -- ( Li ) -- 11 -- ( Li ) -- 12 -- ( He ) -- 13 -- ( He ) -- 14 -- ( Li ) -- 15 -- ( H ) -- 16 --
#
# Select a Move
# > 10, Reward: 0
#
# 	    Turns Taken: 18     ||     Score: 8     ||     Atom Count: 17
#
# 				Center Element: ( He )
#
#  -- 0 -- ( Li ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( He ) -- 5 -- ( + ) -- 6 -- ( H ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 -- ( H ) -- 11 -- ( Li ) -- 12 -- ( Li ) -- 13 -- ( He ) -- 14 -- ( He ) -- 15 -- ( Li ) -- 16 -- ( H ) -- 17 --
#
# Select a Move
# > 12, Reward: 0
#
# 	    Turns Taken: 19     ||     Score: 8     ||     Atom Count: 18
#
# 				Center Element: ( He )
#
#  -- 0 -- ( Li ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( He ) -- 5 -- ( + ) -- 6 -- ( H ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 -- ( H ) -- 11 -- ( Li ) -- 12 -- ( He ) -- 13 -- ( Li ) -- 14 -- ( He ) -- 15 -- ( He ) -- 16 -- ( Li ) -- 17 -- ( H ) -- 18 --
#
# Select a Move
# > 10, Reward: -10
#
# GAME OVER || FINAL SCORE: 46
# STEP 20500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 26.593278884887695
# STEP 21000 | PHASE train | ACTION 0 | REWARD 6 | LOSS 16.9653263092041
# STEP 21500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 18.36497688293457
# STEP 22000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 2.5661239624023438
# STEP 22500 | PHASE train | ACTION 3 | REWARD 0 | LOSS 21.752403259277344
# STEP 23000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 13.781832695007324
# STEP 23500 | PHASE train | ACTION 4 | REWARD 0 | LOSS 46.61144256591797
# STEP 24000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 3.5731148719787598
# STEP 24500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 45.30496597290039
# STEP 25000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 27.92534637451172
# STEP 25500 | PHASE train | ACTION 12 | REWARD 0 | LOSS 16.561298370361328
# STEP 26000 | PHASE train | ACTION 11 | REWARD 0 | LOSS 7.64204216003418
# STEP 26500 | PHASE train | ACTION 0 | REWARD 0.0 | LOSS 4.490779876708984
# STEP 27000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 10.23267936706543
# STEP 27500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 2.614419937133789
# STEP 28000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 21.214244842529297
# STEP 28500 | PHASE train | ACTION 0 | REWARD 0.0 | LOSS 2.0435023307800293
# STEP 29000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 21.901920318603516
# STEP 29500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 7.053980350494385
# STEP 30000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 3.682664155960083
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: dqn_model\assets
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
#
# 	    Turns Taken: 0     ||     Score: 0     ||     Atom Count: 6
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( He ) -- 5 -- ( Li ) -- 6 --
#
# Select a Move
# > 2, Reward: 0
#
# 	    Turns Taken: 1     ||     Score: 0     ||     Atom Count: 7
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( H ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 --
#
# Select a Move
# > 5, Reward: 0
#
# 	    Turns Taken: 2     ||     Score: 0     ||     Atom Count: 8
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( H ) -- 4 -- ( Li ) -- 5 -- ( Li ) -- 6 -- ( He ) -- 7 -- ( Li ) -- 8 --
#
# Select a Move
# > 1, Reward: 0
#
# 	    Turns Taken: 3     ||     Score: 0     ||     Atom Count: 9
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( H ) -- 5 -- ( Li ) -- 6 -- ( Li ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 --
#
# Select a Move
# > 8, Reward: 0
#
# 	    Turns Taken: 4     ||     Score: 0     ||     Atom Count: 10
#
# 				Center Element: ( - )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( H ) -- 5 -- ( Li ) -- 6 -- ( Li ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 --
#
# Select a Move
# > 0, Reward: 0
#
# 	    Turns Taken: 4     ||     Score: 0     ||     Atom Count: 9
#
# 				Center Element: ( He )
#
#  -- 0 -- ( Li ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( H ) -- 4 -- ( Li ) -- 5 -- ( Li ) -- 6 -- ( He ) -- 7 -- ( Li ) -- 8 -- ( Li ) -- 9 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 5     ||     Score: 0     ||     Atom Count: 10
#
# 				Center Element: ( + )
#
#  -- 0 -- ( Li ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( H ) -- 4 -- ( He ) -- 5 -- ( Li ) -- 6 -- ( Li ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 --
#
# Select a Move
# > 0, Reward: 16
#
# 	    Turns Taken: 6     ||     Score: 16     ||     Atom Count: 7
#
# 				Center Element: ( He )
#
#  -- 0 -- ( B ) -- 1 -- ( H ) -- 2 -- ( H ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 -- ( Li ) -- 6 -- ( He ) -- 7 --
#
# Select a Move
# > 3, Reward: 0
#
# 	    Turns Taken: 7     ||     Score: 16     ||     Atom Count: 8
#
# 				Center Element: ( + )
#
#  -- 0 -- ( B ) -- 1 -- ( H ) -- 2 -- ( H ) -- 3 -- ( He ) -- 4 -- ( He ) -- 5 -- ( Li ) -- 6 -- ( Li ) -- 7 -- ( He ) -- 8 --
#
# Select a Move
# > 0, Reward: 0
#
# 	    Turns Taken: 8     ||     Score: 16     ||     Atom Count: 9
#
# 				Center Element: ( + )
#
#  -- 0 -- ( + ) -- 1 -- ( B ) -- 2 -- ( H ) -- 3 -- ( H ) -- 4 -- ( He ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( He ) -- 9 --
#
# Select a Move
# > 7, Reward: 25
#
# 	    Turns Taken: 9     ||     Score: 41     ||     Atom Count: 4
#
# 				Center Element: ( H )
#
#  -- 0 -- ( C ) -- 1 -- ( H ) -- 2 -- ( H ) -- 3 -- ( He ) -- 4 --
#
# Select a Move
# > 1, Reward: 0
#
# 	    Turns Taken: 10     ||     Score: 41     ||     Atom Count: 5
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( C ) -- 1 -- ( H ) -- 2 -- ( H ) -- 3 -- ( H ) -- 4 -- ( He ) -- 5 --
#
# Select a Move
# > 1, Reward: 0
#
# 	    Turns Taken: 11     ||     Score: 41     ||     Atom Count: 6
#
# 				Center Element: ( + )
#
#  -- 0 -- ( C ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( H ) -- 4 -- ( H ) -- 5 -- ( He ) -- 6 --
#
# Select a Move
# > 2, Reward: 0
#
# 	    Turns Taken: 12     ||     Score: 41     ||     Atom Count: 7
#
# 				Center Element: ( He )
#
#  -- 0 -- ( C ) -- 1 -- ( Li ) -- 2 -- ( + ) -- 3 -- ( H ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( He ) -- 7 --
#
# Select a Move
# > 1, Reward: 0
#
# 	    Turns Taken: 13     ||     Score: 41     ||     Atom Count: 8
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( Li ) -- 3 -- ( + ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( H ) -- 7 -- ( He ) -- 8 --
#
# Select a Move
# > 2, Reward: 0
#
# 	    Turns Taken: 14     ||     Score: 41     ||     Atom Count: 9
#
# 				Center Element: ( + )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( Li ) -- 3 -- ( Li ) -- 4 -- ( + ) -- 5 -- ( H ) -- 6 -- ( H ) -- 7 -- ( H ) -- 8 -- ( He ) -- 9 --
#
# Select a Move
# > 2, Reward: 0
#
# 	    Turns Taken: 15     ||     Score: 41     ||     Atom Count: 10
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( + ) -- 6 -- ( H ) -- 7 -- ( H ) -- 8 -- ( H ) -- 9 -- ( He ) -- 10 --
#
# Select a Move
# > 6, Reward: 6
#
# 	    Turns Taken: 16     ||     Score: 47     ||     Atom Count: 9
#
# 				Center Element: ( - )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( H ) -- 6 -- ( H ) -- 7 -- ( H ) -- 8 -- ( He ) -- 9 --
#
# Select a Move
# > 7, Reward: 0
#
# 	    Turns Taken: 16     ||     Score: 47     ||     Atom Count: 8
#
# 				Center Element: ( H )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( H ) -- 6 -- ( H ) -- 7 -- ( He ) -- 8 --
#
# Select a Move
# > 7, Reward: 0
#
# 	    Turns Taken: 17     ||     Score: 47     ||     Atom Count: 9
#
# 				Center Element: ( He )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( H ) -- 6 -- ( H ) -- 7 -- ( H ) -- 8 -- ( He ) -- 9 --
#
# Select a Move
# > 8, Reward: 0
#
# 	    Turns Taken: 18     ||     Score: 47     ||     Atom Count: 10
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( H ) -- 6 -- ( H ) -- 7 -- ( H ) -- 8 -- ( He ) -- 9 -- ( He ) -- 10 --
#
# Select a Move
# > 7, Reward: 0
#
# 	    Turns Taken: 19     ||     Score: 47     ||     Atom Count: 11
#
# 				Center Element: ( + )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( H ) -- 6 -- ( H ) -- 7 -- ( Li ) -- 8 -- ( H ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 --
#
# Select a Move
# > 8, Reward: 0
#
# 	    Turns Taken: 20     ||     Score: 47     ||     Atom Count: 12
#
# 				Center Element: ( H )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( H ) -- 6 -- ( H ) -- 7 -- ( Li ) -- 8 -- ( + ) -- 9 -- ( H ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 --
#
# Select a Move
# > 9, Reward: 0
#
# 	    Turns Taken: 21     ||     Score: 47     ||     Atom Count: 13
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( H ) -- 6 -- ( H ) -- 7 -- ( Li ) -- 8 -- ( + ) -- 9 -- ( H ) -- 10 -- ( H ) -- 11 -- ( He ) -- 12 -- ( He ) -- 13 --
#
# Select a Move
# > 7, Reward: 0
#
# 	    Turns Taken: 22     ||     Score: 47     ||     Atom Count: 14
#
# 				Center Element: ( + )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( H ) -- 6 -- ( H ) -- 7 -- ( Li ) -- 8 -- ( Li ) -- 9 -- ( + ) -- 10 -- ( H ) -- 11 -- ( H ) -- 12 -- ( He ) -- 13 -- ( He ) -- 14 --
#
# Select a Move
# > 5, Reward: 0
#
# 	    Turns Taken: 23     ||     Score: 47     ||     Atom Count: 15
#
# 				Center Element: ( + )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( + ) -- 6 -- ( H ) -- 7 -- ( H ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 -- ( + ) -- 11 -- ( H ) -- 12 -- ( H ) -- 13 -- ( He ) -- 14 -- ( He ) -- 15 --
#
# Select a Move
# > 14, Reward: 4
#
# 	    Turns Taken: 24     ||     Score: 51     ||     Atom Count: 14
#
# 				Center Element: ( H )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( + ) -- 6 -- ( H ) -- 7 -- ( H ) -- 8 -- ( Li ) -- 9 -- ( Li ) -- 10 -- ( + ) -- 11 -- ( H ) -- 12 -- ( H ) -- 13 -- ( Li ) -- 14 --
#
# Select a Move
# > 7, Reward: 0
#
# 	    Turns Taken: 25     ||     Score: 51     ||     Atom Count: 15
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( + ) -- 6 -- ( H ) -- 7 -- ( H ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( Li ) -- 11 -- ( + ) -- 12 -- ( H ) -- 13 -- ( H ) -- 14 -- ( Li ) -- 15 --
#
# Select a Move
# > 12, Reward: 6
#
# 	    Turns Taken: 26     ||     Score: 57     ||     Atom Count: 14
#
# 				Center Element: ( He )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( + ) -- 6 -- ( H ) -- 7 -- ( H ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( Be ) -- 11 -- ( H ) -- 12 -- ( H ) -- 13 -- ( Li ) -- 14 --
#
# Select a Move
# > 12, Reward: 0
#
# 	    Turns Taken: 27     ||     Score: 57     ||     Atom Count: 15
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( + ) -- 6 -- ( H ) -- 7 -- ( H ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( Be ) -- 11 -- ( H ) -- 12 -- ( He ) -- 13 -- ( H ) -- 14 -- ( Li ) -- 15 --
#
# Select a Move
# > 12, Reward: 0
#
# 	    Turns Taken: 28     ||     Score: 57     ||     Atom Count: 16
#
# 				Center Element: ( + )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( + ) -- 6 -- ( H ) -- 7 -- ( H ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( Be ) -- 11 -- ( H ) -- 12 -- ( Li ) -- 13 -- ( He ) -- 14 -- ( H ) -- 15 -- ( Li ) -- 16 --
#
# Select a Move
# > 14, Reward: 0
#
# 	    Turns Taken: 29     ||     Score: 57     ||     Atom Count: 17
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( + ) -- 6 -- ( H ) -- 7 -- ( H ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( Be ) -- 11 -- ( H ) -- 12 -- ( Li ) -- 13 -- ( He ) -- 14 -- ( + ) -- 15 -- ( H ) -- 16 -- ( Li ) -- 17 --
#
# Select a Move
# > 12, Reward: 0
#
# 	    Turns Taken: 30     ||     Score: 57     ||     Atom Count: 18
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( C ) -- 1 -- ( He ) -- 2 -- ( + ) -- 3 -- ( Li ) -- 4 -- ( Be ) -- 5 -- ( + ) -- 6 -- ( H ) -- 7 -- ( H ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( Be ) -- 11 -- ( H ) -- 12 -- ( Li ) -- 13 -- ( Li ) -- 14 -- ( He ) -- 15 -- ( + ) -- 16 -- ( H ) -- 17 -- ( Li ) -- 18 --
#
# Select a Move
# > 12, Reward: -10
#
# GAME OVER || FINAL SCORE: 98
# STEP 30500 | PHASE train | ACTION 0 | REWARD 4 | LOSS 11.155010223388672
# STEP 31000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 6.544841289520264
# STEP 31500 | PHASE train | ACTION 0 | REWARD -10 | LOSS 5.928590774536133
# STEP 32000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 4.698334217071533
# STEP 32500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 5.945699691772461
# STEP 33000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 13.444365501403809
# STEP 33500 | PHASE train | ACTION 11 | REWARD 0 | LOSS 4.639960289001465
# STEP 34000 | PHASE train | ACTION 0 | REWARD -10 | LOSS 14.738981246948242
# STEP 34500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 3.627377986907959
# STEP 35000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 19.11822509765625
# STEP 35500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 14.664274215698242
# STEP 36000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 2.12020206451416
# STEP 36500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 8.33176040649414
# STEP 37000 | PHASE train | ACTION 3 | REWARD 0 | LOSS 2.4393930435180664
# STEP 37500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 2.116575241088867
# STEP 38000 | PHASE train | ACTION 2 | REWARD 0 | LOSS 9.292975425720215
# STEP 38500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 5.174068450927734
# STEP 39000 | PHASE train | ACTION 0 | REWARD 3.0 | LOSS 34.04198455810547
# STEP 39500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 2.866814613342285
# STEP 40000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 9.005091667175293
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: dqn_model\assets
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
#
# 	    Turns Taken: 0     ||     Score: 0     ||     Atom Count: 6
#
# 				Center Element: ( He )
#
#  -- 0 -- ( Li ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( He ) -- 5 -- ( He ) -- 6 --
#
# Select a Move
# > 2, Reward: 0
#
# 	    Turns Taken: 1     ||     Score: 0     ||     Atom Count: 7
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( Li ) -- 1 -- ( Li ) -- 2 -- ( He ) -- 3 -- ( H ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( He ) -- 7 --
#
# Select a Move
# > 3, Reward: 0
#
# 	    Turns Taken: 2     ||     Score: 0     ||     Atom Count: 8
#
# 				Center Element: ( He )
#
#  -- 0 -- ( Li ) -- 1 -- ( Li ) -- 2 -- ( He ) -- 3 -- ( Li ) -- 4 -- ( H ) -- 5 -- ( Li ) -- 6 -- ( He ) -- 7 -- ( He ) -- 8 --
#
# Select a Move
# > 7, Reward: 0
#
# 	    Turns Taken: 3     ||     Score: 0     ||     Atom Count: 9
#
# 				Center Element: ( He )
#
#  -- 0 -- ( Li ) -- 1 -- ( Li ) -- 2 -- ( He ) -- 3 -- ( Li ) -- 4 -- ( H ) -- 5 -- ( Li ) -- 6 -- ( He ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 --
#
# Select a Move
# > 8, Reward: 0
#
# 	    Turns Taken: 4     ||     Score: 0     ||     Atom Count: 10
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( Li ) -- 1 -- ( Li ) -- 2 -- ( He ) -- 3 -- ( Li ) -- 4 -- ( H ) -- 5 -- ( Li ) -- 6 -- ( He ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 -- ( He ) -- 10 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 5     ||     Score: 0     ||     Atom Count: 11
#
# 				Center Element: ( + )
#
#  -- 0 -- ( Li ) -- 1 -- ( Li ) -- 2 -- ( He ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( H ) -- 6 -- ( Li ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 --
#
# Select a Move
# > 0, Reward: 0
#
# 	    Turns Taken: 6     ||     Score: 0     ||     Atom Count: 12
#
# 				Center Element: ( H )
#
#  -- 0 -- ( + ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 -- ( Li ) -- 6 -- ( H ) -- 7 -- ( Li ) -- 8 -- ( He ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 --
#
# Select a Move
# > 3, Reward: 0
#
# 	    Turns Taken: 7     ||     Score: 0     ||     Atom Count: 13
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( + ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( He ) -- 5 -- ( Li ) -- 6 -- ( Li ) -- 7 -- ( H ) -- 8 -- ( Li ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( He ) -- 13 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 8     ||     Score: 0     ||     Atom Count: 14
#
# 				Center Element: ( He )
#
#  -- 0 -- ( + ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( He ) -- 13 -- ( He ) -- 14 --
#
# Select a Move
# > 0, Reward: 0
#
# 	    Turns Taken: 9     ||     Score: 0     ||     Atom Count: 15
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( Li ) -- 4 -- ( H ) -- 5 -- ( Li ) -- 6 -- ( He ) -- 7 -- ( Li ) -- 8 -- ( Li ) -- 9 -- ( H ) -- 10 -- ( Li ) -- 11 -- ( He ) -- 12 -- ( He ) -- 13 -- ( He ) -- 14 -- ( He ) -- 15 --
#
# Select a Move
# > 0, Reward: 10
#
# 	    Turns Taken: 10     ||     Score: 10     ||     Atom Count: 12
#
# 				Center Element: ( H )
#
#  -- 0 -- ( Be ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( He ) -- 5 -- ( Li ) -- 6 -- ( Li ) -- 7 -- ( H ) -- 8 -- ( Li ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 11     ||     Score: 10     ||     Atom Count: 13
#
# 				Center Element: ( He )
#
#  -- 0 -- ( Be ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( H ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( He ) -- 13 --
#
# Select a Move
# > 12, Reward: 0
#
# 	    Turns Taken: 12     ||     Score: 10     ||     Atom Count: 14
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( Be ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( H ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( He ) -- 13 -- ( He ) -- 14 --
#
# Select a Move
# > 12, Reward: 0
#
# 	    Turns Taken: 13     ||     Score: 10     ||     Atom Count: 15
#
# 				Center Element: ( He )
#
#  -- 0 -- ( Be ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( H ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( Li ) -- 13 -- ( He ) -- 14 -- ( He ) -- 15 --
#
# Select a Move
# > 12, Reward: 0
#
# 	    Turns Taken: 14     ||     Score: 10     ||     Atom Count: 16
#
# 				Center Element: ( + )
#
#  -- 0 -- ( Be ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( H ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( He ) -- 13 -- ( Li ) -- 14 -- ( He ) -- 15 -- ( He ) -- 16 --
#
# Select a Move
# > 12, Reward: 4
#
# 	    Turns Taken: 15     ||     Score: 14     ||     Atom Count: 15
#
# 				Center Element: ( He )
#
#  -- 0 -- ( Be ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( H ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( He ) -- 11 -- ( Li ) -- 12 -- ( Li ) -- 13 -- ( He ) -- 14 -- ( He ) -- 15 --
#
# Select a Move
# > 12, Reward: 0
#
# 	    Turns Taken: 16     ||     Score: 14     ||     Atom Count: 16
#
# 				Center Element: ( H )
#
#  -- 0 -- ( Be ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( H ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( He ) -- 11 -- ( Li ) -- 12 -- ( He ) -- 13 -- ( Li ) -- 14 -- ( He ) -- 15 -- ( He ) -- 16 --
#
# Select a Move
# > 12, Reward: 0
#
# 	    Turns Taken: 17     ||     Score: 14     ||     Atom Count: 17
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( Be ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( H ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( He ) -- 11 -- ( Li ) -- 12 -- ( H ) -- 13 -- ( He ) -- 14 -- ( Li ) -- 15 -- ( He ) -- 16 -- ( He ) -- 17 --
#
# Select a Move
# > 12, Reward: 0
#
# 	    Turns Taken: 18     ||     Score: 14     ||     Atom Count: 18
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( Be ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( H ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( He ) -- 11 -- ( Li ) -- 12 -- ( Li ) -- 13 -- ( H ) -- 14 -- ( He ) -- 15 -- ( Li ) -- 16 -- ( He ) -- 17 -- ( He ) -- 18 --
#
# Select a Move
# > 12, Reward: -10
#
# GAME OVER || FINAL SCORE: 59
# STEP 40500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 2.662060260772705
# STEP 41000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 1.955143928527832
# STEP 41500 | PHASE train | ACTION 11 | REWARD 0 | LOSS 15.582036018371582
# STEP 42000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 21.33620834350586
# STEP 42500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 5.174685478210449
# STEP 43000 | PHASE train | ACTION 4 | REWARD 6 | LOSS 3.337211847305298
# STEP 43500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 4.957430839538574
# STEP 44000 | PHASE train | ACTION 5 | REWARD 0 | LOSS 2.2061023712158203
# STEP 44500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 17.371978759765625
# STEP 45000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 5.0300445556640625
# STEP 45500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 9.238893508911133
# STEP 46000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 5.805294990539551
# STEP 46500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 16.42513656616211
# STEP 47000 | PHASE train | ACTION 4 | REWARD 0 | LOSS 25.977371215820312
# STEP 47500 | PHASE train | ACTION 0 | REWARD 17.0 | LOSS 11.397807121276855
# STEP 48000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 8.76594352722168
# STEP 48500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 2.2930469512939453
# STEP 49000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 43.747642517089844
# STEP 49500 | PHASE train | ACTION 0 | REWARD 6 | LOSS 7.386338233947754
# STEP 50000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 19.128917694091797
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: dqn_model\assets
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
#
# 	    Turns Taken: 0     ||     Score: 0     ||     Atom Count: 6
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( He ) -- 3 -- ( Li ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 --
#
# Select a Move
# > 2, Reward: 0
#
# 	    Turns Taken: 1     ||     Score: 0     ||     Atom Count: 7
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 -- ( H ) -- 6 -- ( H ) -- 7 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 2     ||     Score: 0     ||     Atom Count: 8
#
# 				Center Element: ( He )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( He ) -- 4 -- ( H ) -- 5 -- ( Li ) -- 6 -- ( H ) -- 7 -- ( H ) -- 8 --
#
# Select a Move
# > 5, Reward: 0
#
# 	    Turns Taken: 3     ||     Score: 0     ||     Atom Count: 9
#
# 				Center Element: ( He )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( He ) -- 4 -- ( H ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( H ) -- 8 -- ( H ) -- 9 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 4     ||     Score: 0     ||     Atom Count: 10
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( He ) -- 4 -- ( He ) -- 5 -- ( H ) -- 6 -- ( He ) -- 7 -- ( Li ) -- 8 -- ( H ) -- 9 -- ( H ) -- 10 --
#
# Select a Move
# > 1, Reward: 0
#
# 	    Turns Taken: 5     ||     Score: 0     ||     Atom Count: 11
#
# 				Center Element: ( He )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( Li ) -- 4 -- ( He ) -- 5 -- ( He ) -- 6 -- ( H ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 -- ( H ) -- 10 -- ( H ) -- 11 --
#
# Select a Move
# > 8, Reward: 0
#
# 	    Turns Taken: 6     ||     Score: 0     ||     Atom Count: 12
#
# 				Center Element: ( He )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( Li ) -- 4 -- ( He ) -- 5 -- ( He ) -- 6 -- ( H ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 -- ( Li ) -- 10 -- ( H ) -- 11 -- ( H ) -- 12 --
#
# Select a Move
# > 8, Reward: 0
#
# 	    Turns Taken: 7     ||     Score: 0     ||     Atom Count: 13
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( Li ) -- 4 -- ( He ) -- 5 -- ( He ) -- 6 -- ( H ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 -- ( He ) -- 10 -- ( Li ) -- 11 -- ( H ) -- 12 -- ( H ) -- 13 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 8     ||     Score: 0     ||     Atom Count: 14
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( He ) -- 7 -- ( H ) -- 8 -- ( He ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( Li ) -- 12 -- ( H ) -- 13 -- ( H ) -- 14 --
#
# Select a Move
# > 8, Reward: 0
#
# 	    Turns Taken: 9     ||     Score: 0     ||     Atom Count: 15
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( He ) -- 7 -- ( H ) -- 8 -- ( H ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( Li ) -- 13 -- ( H ) -- 14 -- ( H ) -- 15 --
#
# Select a Move
# > 10, Reward: 4
#
# 	    Turns Taken: 10     ||     Score: 4     ||     Atom Count: 14
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( He ) -- 7 -- ( H ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 -- ( He ) -- 11 -- ( Li ) -- 12 -- ( H ) -- 13 -- ( H ) -- 14 --
#
# Select a Move
# > 7, Reward: 0
#
# 	    Turns Taken: 11     ||     Score: 4     ||     Atom Count: 15
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( He ) -- 7 -- ( + ) -- 8 -- ( H ) -- 9 -- ( H ) -- 10 -- ( Li ) -- 11 -- ( He ) -- 12 -- ( Li ) -- 13 -- ( H ) -- 14 -- ( H ) -- 15 --
#
# Select a Move
# > 10, Reward: 0
#
# 	    Turns Taken: 12     ||     Score: 4     ||     Atom Count: 16
#
# 				Center Element: ( - )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( He ) -- 7 -- ( + ) -- 8 -- ( H ) -- 9 -- ( H ) -- 10 -- ( + ) -- 11 -- ( Li ) -- 12 -- ( He ) -- 13 -- ( Li ) -- 14 -- ( H ) -- 15 -- ( H ) -- 16 --
#
# Select a Move
# > 14, Reward: 0
#
# 	    Turns Taken: 12     ||     Score: 4     ||     Atom Count: 15
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( He ) -- 7 -- ( + ) -- 8 -- ( H ) -- 9 -- ( H ) -- 10 -- ( + ) -- 11 -- ( Li ) -- 12 -- ( He ) -- 13 -- ( Li ) -- 14 -- ( H ) -- 15 --
#
# Select a Move
# > 7, Reward: 3
#
# 	    Turns Taken: 13     ||     Score: 7     ||     Atom Count: 14
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( He ) -- 7 -- ( He ) -- 8 -- ( H ) -- 9 -- ( + ) -- 10 -- ( Li ) -- 11 -- ( He ) -- 12 -- ( Li ) -- 13 -- ( H ) -- 14 --
#
# Select a Move
# > 2, Reward: 0
#
# 	    Turns Taken: 14     ||     Score: 7     ||     Atom Count: 15
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( Li ) -- 6 -- ( He ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 -- ( H ) -- 10 -- ( + ) -- 11 -- ( Li ) -- 12 -- ( He ) -- 13 -- ( Li ) -- 14 -- ( H ) -- 15 --
#
# Select a Move
# > 6, Reward: 0
#
# 	    Turns Taken: 15     ||     Score: 7     ||     Atom Count: 16
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( Li ) -- 6 -- ( + ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 -- ( He ) -- 10 -- ( H ) -- 11 -- ( + ) -- 12 -- ( Li ) -- 13 -- ( He ) -- 14 -- ( Li ) -- 15 -- ( H ) -- 16 --
#
# Select a Move
# > 12, Reward: 3
#
# 	    Turns Taken: 16     ||     Score: 10     ||     Atom Count: 15
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( Li ) -- 6 -- ( + ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( Li ) -- 12 -- ( He ) -- 13 -- ( Li ) -- 14 -- ( H ) -- 15 --
#
# Select a Move
# > 8, Reward: 0
#
# 	    Turns Taken: 17     ||     Score: 10     ||     Atom Count: 16
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( Li ) -- 6 -- ( + ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( Li ) -- 13 -- ( He ) -- 14 -- ( Li ) -- 15 -- ( H ) -- 16 --
#
# Select a Move
# > 12, Reward: 0
#
# 	    Turns Taken: 18     ||     Score: 10     ||     Atom Count: 17
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( Li ) -- 6 -- ( + ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( Li ) -- 13 -- ( Li ) -- 14 -- ( He ) -- 15 -- ( Li ) -- 16 -- ( H ) -- 17 --
#
# Select a Move
# > 12, Reward: 0
#
# 	    Turns Taken: 19     ||     Score: 10     ||     Atom Count: 18
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( Li ) -- 6 -- ( + ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( H ) -- 13 -- ( Li ) -- 14 -- ( Li ) -- 15 -- ( He ) -- 16 -- ( Li ) -- 17 -- ( H ) -- 18 --
#
# Select a Move
# > 14, Reward: 6
#
# 	    Turns Taken: 20     ||     Score: 16     ||     Atom Count: 17
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( Li ) -- 6 -- ( + ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( H ) -- 13 -- ( Be ) -- 14 -- ( He ) -- 15 -- ( Li ) -- 16 -- ( H ) -- 17 --
#
# Select a Move
# > 14, Reward: 0
#
# 	    Turns Taken: 21     ||     Score: 16     ||     Atom Count: 18
#
# 				Center Element: ( He )
#
#  -- 0 -- ( He ) -- 1 -- ( + ) -- 2 -- ( H ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( Li ) -- 6 -- ( + ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( H ) -- 13 -- ( Be ) -- 14 -- ( H ) -- 15 -- ( He ) -- 16 -- ( Li ) -- 17 -- ( H ) -- 18 --
#
# Select a Move
# > 12, Reward: -10
#
# GAME OVER || FINAL SCORE: 53
# STEP 50500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 7.0652008056640625
# STEP 51000 | PHASE train | ACTION 10 | REWARD 4 | LOSS 5.941038131713867
# STEP 51500 | PHASE train | ACTION 0 | REWARD 0.0 | LOSS 16.061302185058594
# STEP 52000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 16.664106369018555
# STEP 52500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 5.468425273895264
# STEP 53000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 10.714488983154297
# STEP 53500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 15.979658126831055
# STEP 54000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 6.925458908081055
# STEP 54500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 7.713502883911133
# STEP 55000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 1.997840166091919
# STEP 55500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 4.951568603515625
# STEP 56000 | PHASE train | ACTION 11 | REWARD 0 | LOSS 18.145092010498047
# STEP 56500 | PHASE train | ACTION 4 | REWARD 0.0 | LOSS 5.13535213470459
# STEP 57000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 6.215873718261719
# STEP 57500 | PHASE train | ACTION 0 | REWARD 0 | LOSS 2.444634199142456
# STEP 58000 | PHASE train | ACTION 0 | REWARD 0.0 | LOSS 7.798674583435059
# STEP 58500 | PHASE train | ACTION 0 | REWARD 3.0 | LOSS 23.166725158691406
# STEP 59000 | PHASE train | ACTION 0 | REWARD 0.0 | LOSS 5.9560465812683105
# STEP 59500 | PHASE train | ACTION 0 | REWARD 4 | LOSS 9.846263885498047
# STEP 60000 | PHASE train | ACTION 0 | REWARD 0 | LOSS 3.0864107608795166
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: dqn_model\assets
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
#
# 	    Turns Taken: 0     ||     Score: 0     ||     Atom Count: 6
#
# 				Center Element: ( + )
#
#  -- 0 -- ( H ) -- 1 -- ( H ) -- 2 -- ( He ) -- 3 -- ( Li ) -- 4 -- ( Li ) -- 5 -- ( Li ) -- 6 --
#
# Select a Move
# > 0, Reward: 0
#
# 	    Turns Taken: 1     ||     Score: 0     ||     Atom Count: 7
#
# 				Center Element: ( + )
#
#  -- 0 -- ( + ) -- 1 -- ( H ) -- 2 -- ( H ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 -- ( Li ) -- 6 -- ( Li ) -- 7 --
#
# Select a Move
# > 0, Reward: 0
#
# 	    Turns Taken: 2     ||     Score: 0     ||     Atom Count: 8
#
# 				Center Element: ( + )
#
#  -- 0 -- ( + ) -- 1 -- ( + ) -- 2 -- ( H ) -- 3 -- ( H ) -- 4 -- ( He ) -- 5 -- ( Li ) -- 6 -- ( Li ) -- 7 -- ( Li ) -- 8 --
#
# Select a Move
# > 7, Reward: 6
#
# 	    Turns Taken: 3     ||     Score: 6     ||     Atom Count: 7
#
# 				Center Element: ( H )
#
#  -- 0 -- ( + ) -- 1 -- ( + ) -- 2 -- ( H ) -- 3 -- ( H ) -- 4 -- ( He ) -- 5 -- ( Li ) -- 6 -- ( Be ) -- 7 --
#
# Select a Move
# > 0, Reward: 0
#
# 	    Turns Taken: 4     ||     Score: 6     ||     Atom Count: 8
#
# 				Center Element: ( He )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( + ) -- 3 -- ( H ) -- 4 -- ( H ) -- 5 -- ( He ) -- 6 -- ( Li ) -- 7 -- ( Be ) -- 8 --
#
# Select a Move
# > 6, Reward: 0
#
# 	    Turns Taken: 5     ||     Score: 6     ||     Atom Count: 9
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( + ) -- 3 -- ( H ) -- 4 -- ( H ) -- 5 -- ( He ) -- 6 -- ( He ) -- 7 -- ( Li ) -- 8 -- ( Be ) -- 9 --
#
# Select a Move
# > 2, Reward: 0
#
# 	    Turns Taken: 6     ||     Score: 6     ||     Atom Count: 10
#
# 				Center Element: ( He )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( + ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( He ) -- 7 -- ( He ) -- 8 -- ( Li ) -- 9 -- ( Be ) -- 10 --
#
# Select a Move
# > 6, Reward: 0
#
# 	    Turns Taken: 7     ||     Score: 6     ||     Atom Count: 11
#
# 				Center Element: ( + )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( + ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( He ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 -- ( Li ) -- 10 -- ( Be ) -- 11 --
#
# Select a Move
# > 9, Reward: 0
#
# 	    Turns Taken: 8     ||     Score: 6     ||     Atom Count: 12
#
# 				Center Element: ( He )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( + ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( He ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 -- ( + ) -- 10 -- ( Li ) -- 11 -- ( Be ) -- 12 --
#
# Select a Move
# > 8, Reward: 0
#
# 	    Turns Taken: 9     ||     Score: 6     ||     Atom Count: 13
#
# 				Center Element: ( H )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( + ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( He ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 -- ( He ) -- 10 -- ( + ) -- 11 -- ( Li ) -- 12 -- ( Be ) -- 13 --
#
# Select a Move
# > 6, Reward: 0
#
# 	    Turns Taken: 10     ||     Score: 6     ||     Atom Count: 14
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( + ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( H ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( + ) -- 12 -- ( Li ) -- 13 -- ( Be ) -- 14 --
#
# Select a Move
# > 6, Reward: 0
#
# 	    Turns Taken: 11     ||     Score: 6     ||     Atom Count: 15
#
# 				Center Element: ( + )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( + ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( Li ) -- 7 -- ( H ) -- 8 -- ( He ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( + ) -- 13 -- ( Li ) -- 14 -- ( Be ) -- 15 --
#
# Select a Move
# > 8, Reward: 0
#
# 	    Turns Taken: 12     ||     Score: 6     ||     Atom Count: 16
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( + ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( Li ) -- 7 -- ( H ) -- 8 -- ( + ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( He ) -- 13 -- ( + ) -- 14 -- ( Li ) -- 15 -- ( Be ) -- 16 --
#
# Select a Move
# > 14, Reward: 0
#
# 	    Turns Taken: 13     ||     Score: 6     ||     Atom Count: 17
#
# 				Center Element: ( He )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( + ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( Li ) -- 7 -- ( H ) -- 8 -- ( + ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( He ) -- 13 -- ( + ) -- 14 -- ( Li ) -- 15 -- ( Li ) -- 16 -- ( Be ) -- 17 --
#
# Select a Move
# > 14, Reward: 4
#
# 	    Turns Taken: 14     ||     Score: 10     ||     Atom Count: 16
#
# 				Center Element: ( - )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( + ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( Li ) -- 7 -- ( H ) -- 8 -- ( + ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( Li ) -- 13 -- ( Li ) -- 14 -- ( Li ) -- 15 -- ( Be ) -- 16 --
#
# Select a Move
# > 15, Reward: 0
#
# 	    Turns Taken: 14     ||     Score: 10     ||     Atom Count: 15
#
# 				Center Element: ( Be )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( + ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( Li ) -- 7 -- ( H ) -- 8 -- ( + ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( He ) -- 12 -- ( Li ) -- 13 -- ( Li ) -- 14 -- ( Li ) -- 15 --
#
# Select a Move
# > 11, Reward: 0
#
# 	    Turns Taken: 15     ||     Score: 10     ||     Atom Count: 16
#
# 				Center Element: ( He )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( + ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( Li ) -- 7 -- ( H ) -- 8 -- ( + ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( Be ) -- 12 -- ( He ) -- 13 -- ( Li ) -- 14 -- ( Li ) -- 15 -- ( Li ) -- 16 --
#
# Select a Move
# > 13, Reward: 0
#
# 	    Turns Taken: 16     ||     Score: 10     ||     Atom Count: 17
#
# 				Center Element: ( + )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( + ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( Li ) -- 7 -- ( H ) -- 8 -- ( + ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( Be ) -- 12 -- ( He ) -- 13 -- ( He ) -- 14 -- ( Li ) -- 15 -- ( Li ) -- 16 -- ( Li ) -- 17 --
#
# Select a Move
# > 10, Reward: 4
#
# 	    Turns Taken: 17     ||     Score: 14     ||     Atom Count: 16
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( + ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( Li ) -- 7 -- ( H ) -- 8 -- ( + ) -- 9 -- ( Li ) -- 10 -- ( Be ) -- 11 -- ( He ) -- 12 -- ( He ) -- 13 -- ( Li ) -- 14 -- ( Li ) -- 15 -- ( Li ) -- 16 --
#
# Select a Move
# > 15, Reward: 0
#
# 	    Turns Taken: 18     ||     Score: 14     ||     Atom Count: 17
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( H ) -- 1 -- ( + ) -- 2 -- ( Li ) -- 3 -- ( + ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( Li ) -- 7 -- ( H ) -- 8 -- ( + ) -- 9 -- ( Li ) -- 10 -- ( Be ) -- 11 -- ( He ) -- 12 -- ( He ) -- 13 -- ( Li ) -- 14 -- ( Li ) -- 15 -- ( Li ) -- 16 -- ( Li ) -- 17 --
#
# Select a Move
# > 11, Reward: 0
#
# 	    Turns Taken: 19     ||     Score: 14     ||     Atom Count: 18
#
# ...
#
# Select a Move
# > 10, Reward: 0
#
# 	    Turns Taken: 14     ||     Score: 7     ||     Atom Count: 15
#
# 				Center Element: ( H )
#
#  -- 0 -- ( H ) -- 1 -- ( H ) -- 2 -- ( + ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 -- ( H ) -- 6 -- ( H ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 -- ( He ) -- 10 -- ( Li ) -- 11 -- ( He ) -- 12 -- ( Li ) -- 13 -- ( He ) -- 14 -- ( He ) -- 15 --
#
# Select a Move
# > 12, Reward: 0
#
# 	    Turns Taken: 15     ||     Score: 7     ||     Atom Count: 16
#
# 				Center Element: ( H )
#
#  -- 0 -- ( H ) -- 1 -- ( H ) -- 2 -- ( + ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 -- ( H ) -- 6 -- ( H ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 -- ( He ) -- 10 -- ( Li ) -- 11 -- ( He ) -- 12 -- ( H ) -- 13 -- ( Li ) -- 14 -- ( He ) -- 15 -- ( He ) -- 16 --
#
# Select a Move
# > 12, Reward: 0
#
# 	    Turns Taken: 16     ||     Score: 7     ||     Atom Count: 17
#
# 				Center Element: ( H )
#
#  -- 0 -- ( H ) -- 1 -- ( H ) -- 2 -- ( + ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 -- ( H ) -- 6 -- ( H ) -- 7 -- ( He ) -- 8 -- ( He ) -- 9 -- ( He ) -- 10 -- ( Li ) -- 11 -- ( He ) -- 12 -- ( H ) -- 13 -- ( H ) -- 14 -- ( Li ) -- 15 -- ( He ) -- 16 -- ( He ) -- 17 --
#
# Select a Move
# > 2, Reward: 0
#
# 	    Turns Taken: 17     ||     Score: 7     ||     Atom Count: 18
#
# 				Center Element: ( + )
#
#  -- 0 -- ( H ) -- 1 -- ( H ) -- 2 -- ( H ) -- 3 -- ( + ) -- 4 -- ( He ) -- 5 -- ( Li ) -- 6 -- ( H ) -- 7 -- ( H ) -- 8 -- ( He ) -- 9 -- ( He ) -- 10 -- ( He ) -- 11 -- ( Li ) -- 12 -- ( He ) -- 13 -- ( H ) -- 14 -- ( H ) -- 15 -- ( Li ) -- 16 -- ( He ) -- 17 -- ( He ) -- 18 --
#
# Select a Move
# > 4, Reward: -10
#
# GAME OVER || FINAL SCORE: 37
# STEP 1440500 | PHASE train | ACTION 8 | REWARD 0 | LOSS 5.890798091888428
# STEP 1441000 | PHASE train | ACTION 8 | REWARD 0 | LOSS 17.790390014648438
# STEP 1441500 | PHASE train | ACTION 8 | REWARD 0 | LOSS 6.7117462158203125
# STEP 1442000 | PHASE train | ACTION 7 | REWARD 0 | LOSS 6.4813079833984375
# STEP 1442500 | PHASE train | ACTION 8 | REWARD 0 | LOSS 2.93575382232666
# STEP 1443000 | PHASE train | ACTION 7 | REWARD 0 | LOSS 3.7209694385528564
# STEP 1443500 | PHASE train | ACTION 8 | REWARD 0 | LOSS 4.40252685546875
# STEP 1444000 | PHASE train | ACTION 8 | REWARD 0.0 | LOSS 4.504087924957275
# STEP 1444500 | PHASE train | ACTION 4 | REWARD 0 | LOSS 12.202893257141113
# STEP 1445000 | PHASE train | ACTION 8 | REWARD 0 | LOSS 10.25384521484375
# STEP 1445500 | PHASE train | ACTION 4 | REWARD 0 | LOSS 38.16334915161133
# STEP 1446000 | PHASE train | ACTION 8 | REWARD 3 | LOSS 11.330890655517578
# STEP 1446500 | PHASE train | ACTION 4 | REWARD 0 | LOSS 1.4971699714660645
# STEP 1447000 | PHASE train | ACTION 4 | REWARD 0 | LOSS 18.424707412719727
# STEP 1447500 | PHASE train | ACTION 15 | REWARD 3 | LOSS 1.828813910484314
# STEP 1448000 | PHASE train | ACTION 4 | REWARD 0 | LOSS 8.076555252075195
# STEP 1448500 | PHASE train | ACTION 8 | REWARD 0 | LOSS 6.216333866119385
# STEP 1449000 | PHASE train | ACTION 8 | REWARD -10 | LOSS 2.56381893157959
# STEP 1449500 | PHASE train | ACTION 8 | REWARD 0 | LOSS 13.792160987854004
# STEP 1450000 | PHASE train | ACTION 8 | REWARD 0.0 | LOSS 2.2738523483276367
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: dqn_model\assets
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
#
# 	    Turns Taken: 0     ||     Score: 0     ||     Atom Count: 6
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( H ) -- 4 -- ( H ) -- 5 -- ( Li ) -- 6 --
#
# Select a Move
# > 4, Reward: 3
#
# 	    Turns Taken: 1     ||     Score: 3     ||     Atom Count: 5
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 2     ||     Score: 3     ||     Atom Count: 6
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( He ) -- 4 -- ( H ) -- 5 -- ( Li ) -- 6 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 3     ||     Score: 3     ||     Atom Count: 7
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( He ) -- 4 -- ( + ) -- 5 -- ( H ) -- 6 -- ( Li ) -- 7 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 4     ||     Score: 3     ||     Atom Count: 8
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( He ) -- 4 -- ( Li ) -- 5 -- ( + ) -- 6 -- ( H ) -- 7 -- ( Li ) -- 8 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 5     ||     Score: 3     ||     Atom Count: 9
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( He ) -- 4 -- ( + ) -- 5 -- ( Li ) -- 6 -- ( + ) -- 7 -- ( H ) -- 8 -- ( Li ) -- 9 --
#
# Select a Move
# > 4, Reward: 6
#
# 	    Turns Taken: 6     ||     Score: 9     ||     Atom Count: 8
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( H ) -- 3 -- ( He ) -- 4 -- ( Be ) -- 5 -- ( + ) -- 6 -- ( H ) -- 7 -- ( Li ) -- 8 --
#
# Select a Move
# > 2, Reward: 0
#
# 	    Turns Taken: 7     ||     Score: 9     ||     Atom Count: 9
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( He ) -- 5 -- ( Be ) -- 6 -- ( + ) -- 7 -- ( H ) -- 8 -- ( Li ) -- 9 --
#
# Select a Move
# > 7, Reward: 0
#
# 	    Turns Taken: 8     ||     Score: 9     ||     Atom Count: 10
#
# 				Center Element: ( He )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( He ) -- 5 -- ( Be ) -- 6 -- ( + ) -- 7 -- ( H ) -- 8 -- ( H ) -- 9 -- ( Li ) -- 10 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 9     ||     Score: 9     ||     Atom Count: 11
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( He ) -- 5 -- ( He ) -- 6 -- ( Be ) -- 7 -- ( + ) -- 8 -- ( H ) -- 9 -- ( H ) -- 10 -- ( Li ) -- 11 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 10     ||     Score: 9     ||     Atom Count: 12
#
# 				Center Element: ( He )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( + ) -- 5 -- ( He ) -- 6 -- ( He ) -- 7 -- ( Be ) -- 8 -- ( + ) -- 9 -- ( H ) -- 10 -- ( H ) -- 11 -- ( Li ) -- 12 --
#
# Select a Move
# > 4, Reward: 4
#
# 	    Turns Taken: 11     ||     Score: 13     ||     Atom Count: 11
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( Be ) -- 7 -- ( + ) -- 8 -- ( H ) -- 9 -- ( H ) -- 10 -- ( Li ) -- 11 --
#
# Select a Move
# > 8, Reward: 0
#
# 	    Turns Taken: 12     ||     Score: 13     ||     Atom Count: 12
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( Be ) -- 7 -- ( + ) -- 8 -- ( H ) -- 9 -- ( H ) -- 10 -- ( H ) -- 11 -- ( Li ) -- 12 --
#
# Select a Move
# > 8, Reward: 0
#
# 	    Turns Taken: 13     ||     Score: 13     ||     Atom Count: 13
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( Be ) -- 7 -- ( + ) -- 8 -- ( H ) -- 9 -- ( H ) -- 10 -- ( H ) -- 11 -- ( H ) -- 12 -- ( Li ) -- 13 --
#
# Select a Move
# > 8, Reward: 0
#
# 	    Turns Taken: 14     ||     Score: 13     ||     Atom Count: 14
#
# 				Center Element: ( + )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( Li ) -- 5 -- ( He ) -- 6 -- ( Be ) -- 7 -- ( + ) -- 8 -- ( Li ) -- 9 -- ( H ) -- 10 -- ( H ) -- 11 -- ( H ) -- 12 -- ( H ) -- 13 -- ( Li ) -- 14 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 15     ||     Score: 13     ||     Atom Count: 15
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( + ) -- 5 -- ( Li ) -- 6 -- ( He ) -- 7 -- ( Be ) -- 8 -- ( + ) -- 9 -- ( Li ) -- 10 -- ( H ) -- 11 -- ( H ) -- 12 -- ( H ) -- 13 -- ( H ) -- 14 -- ( Li ) -- 15 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 16     ||     Score: 13     ||     Atom Count: 16
#
# 				Center Element: ( He )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( H ) -- 5 -- ( + ) -- 6 -- ( Li ) -- 7 -- ( He ) -- 8 -- ( Be ) -- 9 -- ( + ) -- 10 -- ( Li ) -- 11 -- ( H ) -- 12 -- ( H ) -- 13 -- ( H ) -- 14 -- ( H ) -- 15 -- ( Li ) -- 16 --
#
# Select a Move
# > 10, Reward: 0
#
# 	    Turns Taken: 17     ||     Score: 13     ||     Atom Count: 17
#
# 				Center Element: ( H )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( H ) -- 5 -- ( + ) -- 6 -- ( Li ) -- 7 -- ( He ) -- 8 -- ( Be ) -- 9 -- ( + ) -- 10 -- ( He ) -- 11 -- ( Li ) -- 12 -- ( H ) -- 13 -- ( H ) -- 14 -- ( H ) -- 15 -- ( H ) -- 16 -- ( Li ) -- 17 --
#
# Select a Move
# > 4, Reward: 0
#
# 	    Turns Taken: 18     ||     Score: 13     ||     Atom Count: 18
#
# 				Center Element: ( Li )
#
#  -- 0 -- ( He ) -- 1 -- ( Li ) -- 2 -- ( Li ) -- 3 -- ( H ) -- 4 -- ( H ) -- 5 -- ( H ) -- 6 -- ( + ) -- 7 -- ( Li ) -- 8 -- ( He ) -- 9 -- ( Be ) -- 10 -- ( + ) -- 11 -- ( He ) -- 12 -- ( Li ) -- 13 -- ( H ) -- 14 -- ( H ) -- 15 -- ( H ) -- 16 -- ( H ) -- 17 -- ( Li ) -- 18 --
#
# Select a Move
# > 4, Reward: -10
#
# GAME OVER || FINAL SCORE: 48
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# w:\Documents\atomas\backend\atomas\train.ipynb Cell 7 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/w%3A/Documents/atomas/backend/atomas/train.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> with tf.device(gpu_name):
# ----> <a href='vscode-notebook-cell:/w%3A/Documents/atomas/backend/atomas/train.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>     train_atomas(start_from_ckpt = True)
#
# w:\Documents\atomas\backend\atomas\train.ipynb Cell 7 in train_atomas(start_from_ckpt, ckpt_path)
#      <a href='vscode-notebook-cell:/w%3A/Documents/atomas/backend/atomas/train.ipynb#W6sZmlsZQ%3D%3D?line=12'>13</a> loss_function = keras.losses.MeanSquaredError()
#      <a href='vscode-notebook-cell:/w%3A/Documents/atomas/backend/atomas/train.ipynb#W6sZmlsZQ%3D%3D?line=14'>15</a> # train model
# ---> <a href='vscode-notebook-cell:/w%3A/Documents/atomas/backend/atomas/train.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a> dql_atomas(model = model, optimizer = optimizer, loss_function = loss_function)
#
# w:\Documents\atomas\backend\atomas\train.ipynb Cell 7 in dql_atomas(model, optimizer, loss_function)
#      <a href='vscode-notebook-cell:/w%3A/Documents/atomas/backend/atomas/train.ipynb#W6sZmlsZQ%3D%3D?line=74'>75</a> # train the model on the states and updated Q-values
#      <a href='vscode-notebook-cell:/w%3A/Documents/atomas/backend/atomas/train.ipynb#W6sZmlsZQ%3D%3D?line=75'>76</a> with tf.GradientTape() as tape:
#      <a href='vscode-notebook-cell:/w%3A/Documents/atomas/backend/atomas/train.ipynb#W6sZmlsZQ%3D%3D?line=76'>77</a>
#      <a href='vscode-notebook-cell:/w%3A/Documents/atomas/backend/atomas/train.ipynb#W6sZmlsZQ%3D%3D?line=77'>78</a>     # compute the current Q-values for the samples
# ---> <a href='vscode-notebook-cell:/w%3A/Documents/atomas/backend/atomas/train.ipynb#W6sZmlsZQ%3D%3D?line=78'>79</a>     current_q_value = model(state_sample, training = True)
#      <a href='vscode-notebook-cell:/w%3A/Documents/atomas/backend/atomas/train.ipynb#W6sZmlsZQ%3D%3D?line=79'>80</a>     mask = tf.one_hot(action_sample, NUM_ACTIONS)
#      <a href='vscode-notebook-cell:/w%3A/Documents/atomas/backend/atomas/train.ipynb#W6sZmlsZQ%3D%3D?line=80'>81</a>     current_q_value = tf.reduce_sum(tf.multiply(current_q_value, mask), axis = 1)
#
# File w:\conda\envs\atomas_venv\lib\site-packages\keras\engine\base_layer.py:1037, in Layer.__call__(self, *args, **kwargs)
#    1033   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1035 with autocast_variable.enable_auto_cast_variables(
#    1036     self._compute_dtype_object):
# -> 1037   outputs = call_fn(inputs, *args, **kwargs)
#    1039 if self._activity_regularizer:
#    1040   self._handle_activity_regularization(inputs, outputs)
#
# File w:\conda\envs\atomas_venv\lib\site-packages\keras\engine\functional.py:414, in Functional.call(self, inputs, training, mask)
#     395 @doc_controls.do_not_doc_inheritable
#     396 def call(self, inputs, training=None, mask=None):
#     397   """Calls the model on new inputs.
#     398
#     399   In this case `call` just reapplies
#    (...)
#     412       a list of tensors if there are more than one outputs.
#     413   """
# --> 414   return self._run_internal_graph(
#     415       inputs, training=training, mask=mask)
#
# File w:\conda\envs\atomas_venv\lib\site-packages\keras\engine\functional.py:550, in Functional._run_internal_graph(self, inputs, training, mask)
#     547   continue  # Node is not computable, try skipping.
#     549 args, kwargs = node.map_arguments(tensor_dict)
# --> 550 outputs = node.layer(*args, **kwargs)
#     552 # Update tensor_dict.
#     553 for x_id, y in zip(node.flat_output_ids, tf.nest.flatten(outputs)):
#
# File w:\conda\envs\atomas_venv\lib\site-packages\keras\engine\base_layer.py:1040, in Layer.__call__(self, *args, **kwargs)
#    1037   outputs = call_fn(inputs, *args, **kwargs)
#    1039 if self._activity_regularizer:
# -> 1040   self._handle_activity_regularization(inputs, outputs)
#    1041 if self._supports_masking:
#    1042   self._set_mask_metadata(inputs, outputs, input_masks, not eager)
#
# File w:\conda\envs\atomas_venv\lib\site-packages\keras\engine\base_layer.py:2466, in Layer._handle_activity_regularization(self, inputs, outputs)
#    2464 with backend.name_scope('ActivityRegularizer'):
#    2465   for output in output_list:
# -> 2466     activity_loss = self._activity_regularizer(output)
#    2467     batch_size = tf.cast(
#    2468         tf.shape(output)[0], activity_loss.dtype)
#    2469     # Make activity regularization strength batch-agnostic.
#
# File w:\conda\envs\atomas_venv\lib\site-packages\keras\regularizers.py:317, in L2.__call__(self, x)
#     316 def __call__(self, x):
# --> 317   return self.l2 * tf.reduce_sum(tf.square(x))
#
# File w:\conda\envs\atomas_venv\lib\site-packages\tensorflow\python\ops\math_ops.py:1400, in _OverrideBinaryOperatorHelper.<locals>.r_binary_op_wrapper(y, x)
#    1396 with ops.name_scope(None, op_name, [x, y]) as name:
#    1397   # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1398   #   r_binary_op_wrapper use different force_same_dtype values.
#    1399   y, x = maybe_promote_tensors(y, x)
# -> 1400   return func(x, y, name=name)
#
# File w:\conda\envs\atomas_venv\lib\site-packages\tensorflow\python\ops\math_ops.py:1710, in _mul_dispatch(x, y, name)
#    1708   return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1709 else:
# -> 1710   return multiply(x, y, name=name)
#
# File w:\conda\envs\atomas_venv\lib\site-packages\tensorflow\python\util\dispatch.py:206, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     204 """Call target, and fall back on dispatchers if there is a TypeError."""
#     205 try:
# --> 206   return target(*args, **kwargs)
#     207 except (TypeError, ValueError):
#     208   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     209   # TypeError, when given unexpected types.  So we need to catch both.
#     210   result = dispatch(wrapper, args, kwargs)
#
# File w:\conda\envs\atomas_venv\lib\site-packages\tensorflow\python\ops\math_ops.py:530, in multiply(x, y, name)
#     482 @tf_export("math.multiply", "multiply")
#     483 @dispatch.add_dispatch_support
#     484 def multiply(x, y, name=None):
#     485   """Returns an element-wise x * y.
#     486
#     487   For example:
#    (...)
#     527    * InvalidArgumentError: When `x` and `y` have incompatible shapes or types.
#     528   """
# --> 530   return gen_math_ops.mul(x, y, name)
#
# File w:\conda\envs\atomas_venv\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:6231, in mul(x, y, name)
#    6229 if tld.is_eager:
#    6230   try:
# -> 6231     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6232       _ctx, "Mul", name, x, y)
#    6233     return _result
#    6234   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
